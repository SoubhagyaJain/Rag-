# %% [markdown]
# # 01 - Retrieval Strategy Experiments
#
# The goal of this notebook is to make it dead simple to compare retrieval approaches on the golden set (or a subset).
#
# Ideas to try:
# - Pure dense vs pure BM25
# - Hybrid with different alpha
# - Reranker on / off
# - Parent-child expansion on / off
# - Different embedding models

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / "src"))

from rag.config import load_config
from rag.ingestion.pipeline import IngestionPipeline
from rag.retrieval.factory import build_retriever, ComposedRetriever
from rag.evaluation.harness import load_golden_dataset
