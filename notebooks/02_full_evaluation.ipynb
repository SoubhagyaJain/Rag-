# %% [markdown]
# # 02 - Full Evaluation Runs + Analysis
#
# Run the complete golden set, analyze per-question failures, and compare runs over time.

# %%
from rag.evaluation.harness import EvaluationHarness, run_evaluation
# See scripts/evaluate.py for the canonical way to kick this off with rich output
